# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from regime_ml.data.common.loaders import load_dataframe
from regime_ml.utils.config import load_configs
from regime_ml.regimes.hmm import HMMRegimeDetector

# %%
macro_cfg = load_configs()["macro_data"]["regime_universe"]
macro_processed_path = macro_cfg["processed_path"]
pca_feat_path = macro_cfg["ready_features_path"]
raw_feat_path = macro_cfg["raw_features_path"]
raw_path = macro_cfg["raw_path"]

# %%
df_regimes = load_dataframe("data/regimes/regime_assignments.parquet")
df_regimes
# Out:
#             regime regime_label  filter_proba_0  filter_proba_1  \
# date
# 1990-07-02       1     Recovery   4.358329e-172        1.000000
# 1990-07-03       1     Recovery    1.378664e-06        0.999410
# 1990-07-05       1     Recovery    7.858221e-07        0.999544
# 1990-07-06       1     Recovery    9.094144e-07        0.999608
# 1990-07-09       1     Recovery    7.942091e-07        0.999684
# ...            ...          ...             ...             ...
# 2026-01-16       1     Recovery    1.306802e-08        0.998465
# 2026-01-20       1     Recovery    1.579967e-06        0.694518
# 2026-01-21       1     Recovery    2.614557e-08        0.837415
# 2026-01-22       1     Recovery    1.092749e-08        0.971225
# 2026-01-23       1     Recovery    1.995156e-08        0.992911
#
#             filter_proba_2  filter_proba_3  filter_proba_4
# date
# 1990-07-02    1.156936e-87   2.853231e-308   4.186887e-194
# 1990-07-03    5.886534e-04    3.630674e-11    2.618323e-07
# ...

# %%
regime_names = dict(df_regimes[["regime", "regime_label"]].value_counts().to_dict().keys())

# %%
from regime_ml.regimes.visualisation import plot_ticker_by_regime
fig2 = plot_ticker_by_regime("SPY", df_regimes.index, df_regimes["regime"], regime_names=regime_names)
fig2.show()

# %%
from regime_ml.regimes.visualisation import plot_regime_timeseries

df_feat = load_dataframe("data/features/macro_features_ready.parquet")
proba = df_regimes[["filter_proba_0", "filter_proba_1", "filter_proba_2", "filter_proba_3", "filter_proba_4"]]
fig = plot_regime_timeseries(df_feat, df_regimes["regime"].to_numpy(), proba.to_numpy(), regime_names=regime_names)
fig.show()
