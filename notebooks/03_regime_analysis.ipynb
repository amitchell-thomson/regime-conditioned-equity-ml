# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from regime_ml.data.common.loaders import load_dataframe
from regime_ml.utils.config import load_configs
from regime_ml.regimes.hmm import HMMRegimeDetector
from regime_ml.features.macro.selection import get_top_features

# %%
macro_cfg = load_configs()["macro_data"]["regime_universe"]
feat_path = macro_cfg["raw_features_path"]
raw_path = macro_cfg["raw_path"]

# %%
df_feat = load_dataframe(feat_path)
df_feat = df_feat.dropna() # drop burn-in period

# %%
from regime_ml.regimes.hmm import initialise_emissions
from regime_ml.regimes.hmm import initialise_transitions
from regime_ml.regimes.hmm import initialise_probabilities

fitted_models = {}
count = 0
for n_features in [5]:
    selected_features = get_top_features(n=n_features)
    df_feat_selected = df_feat[selected_features]
    feature_names = df_feat_selected.columns

    for split_date in ["2019-01-01"]: #['2018-01-01','2019-01-01', '2020-01-01', '2021-01-01', '2022-01-01']:
        df_train = df_feat_selected.loc[:split_date]
        X_train = df_train.values
    
        for n_regimes in [4]:
            init_startprob = initialise_probabilities(n_regimes=n_regimes)

            for covariance_type in ['full']:
                init_means, init_covars, scaler = initialise_emissions(df_train, n_clusters=n_regimes, covariance_type=covariance_type)

                for p_stay in [0.9]:
                    init_transmat = initialise_transitions(n_regimes=n_regimes, p_stay=p_stay)

                    model = HMMRegimeDetector(
                        n_regimes=n_regimes,
                        covariance_type=covariance_type,
                        startprob=init_startprob,
                        transmat=init_transmat,
                        means=init_means,
                        covars=init_covars,
                        feature_names=feature_names, # type: ignore
                    )

                    X_train_scaled = scaler.fit_transform(X_train)
                    fitted_model = model.fit(X_train_scaled)
                    fitted_models[f"{count}"] = {
                        "model": fitted_model,
                        "split_date": split_date,
                        "n_features": n_features,
                        "n_regimes": n_regimes,
                        "covariance_type": covariance_type,
                        "p_stay": p_stay,
                        "scaler": scaler,
                    }
                    count += 1

# %%
fitted_models
# Out:
# {'0': {'model': HMMRegimeDetector(is_fitted=True),
#   'split_date': '2019-01-01',
#   'n_features': 5,
#   'n_regimes': 4,
#   'covariance_type': 'full',
#   'p_stay': 0.9,
#   'scaler': StandardScaler()}}

# %%
from regime_ml.regimes.evaluation import compare_hmm_models
results = compare_hmm_models(df_feat, fitted_models)

# %%
pd.DataFrame(results)
# Out:
#                                                                           0
# n_obs_full                                                             5361
# n_obs_is                                                               3594
# n_obs_oos                                                              1767
# regime_stability          {'avg_persistence': 124.67441860465117, 'std_p...
# entropy_balance           {'entropy_balance': 0.019209117019976355, 'ent...
# transition_matrix_sanity  {'median_implied_duration': 223.30821378356868...
# macro_coherence           {'maha_min': 1.8082531147176253, 'maha_median'...
# in_sample                 {'regime_stability': {'avg_persistence': 211.4...
# out_of_sample             {'regime_stability': {'avg_persistence': 65.44...

# %%
records = [
    {"model_id": mid, **pd.json_normalize(v, sep=".").iloc[0].to_dict()}
    for mid, v in results.items()
]
df = pd.DataFrame(records).set_index("model_id")

# %%
# NOTE: investigate why nearly have of the tv_distances are not valid (does this make sense or is there a fundamental issue with the models)
from regime_ml.data.macro import build_featuregroup_map
_map = build_featuregroup_map(df_feat.columns)

# %%
from regime_ml.regimes.selection import select_best_hmm_model
best_id, leaderboard, rejected = select_best_hmm_model(results)
display(leaderboard[["model_id","final_score","macro_score","transition_score","stability_score","oos_macro_score"]])
# Out:
#   model_id  final_score  macro_score  transition_score  stability_score  \
# 0        0     0.871692          1.0          0.572306              1.0
#
#    oos_macro_score
# 0              1.0

# %%
best_model = fitted_models["0"]
model = best_model["model"]
selected_features = model.feature_names
split_date = best_model["split_date"]

best_model
# Out:
# {'model': HMMRegimeDetector(is_fitted=True),
#  'split_date': '2019-01-01',
#  'n_features': 5,
#  'n_regimes': 4,
#  'covariance_type': 'full',
#  'p_stay': 0.7,
#  'scaler': StandardScaler()}

# %%
from regime_ml.regimes.labeling import label_regimes
import numpy as np

df_selected = df_feat[selected_features]
X_full = df_selected.values
X_scaled = best_model["scaler"].fit_transform(X_full)

filtered_proba = model.filter_proba(X_scaled)
filtered_regimes = np.argmax(filtered_proba, axis=1)
smoothed_proba = model.smooth_proba(X_scaled)
predicted_proba = model.forecast_n_steps(filtered_proba, 50)

labels_info = label_regimes(
    X=X_scaled,
    proba=smoothed_proba,
    feature_names=selected_features
)

# %%
from regime_ml.regimes.visualisation import plot_regime_timeseries
from regime_ml.regimes.visualisation import plot_ticker_by_regime

fig1 = plot_regime_timeseries(df_selected, filtered_regimes, predicted_proba, regime_names=labels_info["state_labels"])
fig2 = plot_ticker_by_regime("SPY", df_selected.index, filtered_regimes, regime_names=labels_info["state_labels"])
fig3 = plot_ticker_by_regime("^VIX", df_selected.index, filtered_regimes, regime_names=labels_info["state_labels"])

fig2.show()
fig3.show()
fig1.show()
# Out:
# Downloading SPY data from 2004-09-01 to 2026-01-23...
# Downloading ^VIX data from 2004-09-01 to 2026-01-23...

# %%
from regime_ml.regimes.evaluation import equity_metrics_by_regime
import yfinance as yf
filtered_regimes = list(map(lambda x: labels_info["state_labels"][x], filtered_regimes))

df_sap = yf.download("SAP", start=df_feat.index[0], end=df_feat.index[-2], multi_level_index=False)["Close"].reindex(df_feat.index) # type: ignore

df_equity_metrics = equity_metrics_by_regime(df_sap, filtered_regimes)
df_equity_metrics
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                     regime  n_days  mean_daily_ret  \
# 0       Risk On - Expansion                    587        0.001488
# 1  Risk On - Policy-Contstrained Expansion    2124        0.000606
# 2                    Risk On - Stagflation    1979        0.000573
# 3                     Risk Off - Recession     642       -0.000528
#
#    ann_return   ann_vol    sharpe  max_drawdown  up_day_frac
# 0    0.454604  0.294760  1.272261     -0.212258     0.553663
# 1    0.164834  0.241677  0.631521     -0.373861     0.537194
# 2    0.155419  0.255171  0.566307     -0.378489     0.513896
# 3   -0.124693  0.407587 -0.326667     -0.638359     0.498442

# %%
model0 = fitted_models["0"]["model"]
#model1 = fitted_models["1"]["model"]

# %%
filtered_proba0 = model0.filter_proba(X_scaled)
filtered_regimes0 = np.argmax(filtered_proba0, axis=1)
smoothed_proba0 = model0.smooth_proba(X_scaled)

labels_info0 = label_regimes(
    X=X_scaled,
    proba=smoothed_proba0,
    feature_names=selected_features
)

# filtered_proba1 = model1.filter_proba(X_scaled)
# filtered_regimes1 = np.argmax(filtered_proba1, axis=1)
# smoothed_proba1 = model1.smooth_proba(X_scaled)

# labels_info1 = label_regimes(
#     X=X_scaled,
#     proba=smoothed_proba1,
#     feature_names=selected_features
# )

fig0 = plot_ticker_by_regime("^VIX", df_selected.index, filtered_regimes0, regime_names=labels_info0["state_labels"])
fig1 = plot_ticker_by_regime("^VIX", df_selected.index, filtered_regimes1, regime_names=labels_info1["state_labels"])

fig0.show()
fig1.show()
# Out:
# Downloading ^VIX data from 2004-09-01 to 2026-01-23...
# Downloading ^VIX data from 2004-09-01 to 2026-01-23...

# %%
df_sap = yf.download("SAP", start=df_feat.index[0], end=df_feat.index[-2], multi_level_index=False)["Close"].reindex(df_feat.index) # type: ignore

df_equity_metrics0 = equity_metrics_by_regime(df_sap, filtered_regimes0)
df_equity_metrics1 = equity_metrics_by_regime(df_sap, filtered_regimes1)

display(df_equity_metrics0)
display(df_equity_metrics1)
# Out:
# [*********************100%***********************]  1 of 1 completed
#    regime  n_days  mean_daily_ret  ann_return   ann_vol    sharpe  \
# 0       3     587        0.001488    0.454604  0.294760  1.272261
# 1       0    2124        0.000606    0.164834  0.241677  0.631521
# 2       1    1979        0.000573    0.155419  0.255171  0.566307
# 3       2     642       -0.000528   -0.124693  0.407587 -0.326667
#
#    max_drawdown  up_day_frac
# 0     -0.212258     0.553663
# 1     -0.373861     0.537194
# 2     -0.378489     0.513896
# 3     -0.638359     0.498442
#    regime  n_days  mean_daily_ret  ann_return   ann_vol    sharpe  \
# 0       3     587        0.001488    0.454604  0.294760  1.272261
# 1       0    2124        0.000606    0.164834  0.241677  0.631521
# 2       1    1979        0.000573    0.155419  0.255171  0.566307
# 3       2     642       -0.000528   -0.124693  0.407587 -0.326667
#
#    max_drawdown  up_day_frac
# 0     -0.212258     0.553663
# 1     -0.373861     0.537194
# 2     -0.378489     0.513896
# 3     -0.638359     0.498442
